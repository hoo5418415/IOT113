# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import RFE, SelectKBest, chi2
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import optuna
import joblib

# Load and preprocess the training data
train_df = pd.read_csv('train.csv')
train_df['Age'].fillna(train_df['Age'].median(), inplace=True)
train_df['Embarked'].fillna(train_df['Embarked'].mode()[0], inplace=True)
train_df.drop(['Name', 'Ticket', 'Cabin'], axis=1, inplace=True)
train_df = pd.get_dummies(train_df, columns=['Sex', 'Embarked'], drop_first=True)

# Separate features and target variable
X = train_df.drop('Survived', axis=1)
y = train_df['Survived']

# Feature Selection (RFE)
model = RandomForestClassifier(n_estimators=100, random_state=42)
selector = RFE(model, n_features_to_select=5)
selector.fit(X, y)
selected_features_rfe = X.columns[selector.support_]
print("Selected Features using RFE:", selected_features_rfe.tolist())

# Optuna for hyperparameter optimization
def objective(trial):
    n_estimators = trial.suggest_int('n_estimators', 50, 200)
    max_depth = trial.suggest_int('max_depth', 1, 20)
    
    X_train, X_test, y_train, y_test = train_test_split(X[selected_features_rfe], y, test_size=0.2, random_state=42)
    
    model = RandomForestClassifier(n_estimators=n_estimators, max_depth=max_depth, random_state=42)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    return accuracy

# Run Optuna
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)

print("Best Trial:")
trial = study.best_trial
print(f"  Value: {trial.value}")
print("  Params:")
for key, value in trial.params.items():
    print(f"    {key}: {value}")

# Retrain the model with best parameters
best_params = trial.params
final_model = RandomForestClassifier(n_estimators=best_params['n_estimators'], max_depth=best_params['max_depth'], random_state=42)
final_model.fit(X[selected_features_rfe], y)

# Save the model
joblib.dump(final_model, 'titanic_model.pkl')

# Load and preprocess the test data
test_df = pd.read_csv('test.csv')
test_df['Age'].fillna(test_df['Age'].median(), inplace=True)
test_df['Embarked'].fillna(test_df['Embarked'].mode()[0], inplace=True)
test_df.drop(['Name', 'Ticket', 'Cabin'], axis=1, inplace=True)
test_df = pd.get_dummies(test_df, columns=['Sex', 'Embarked'], drop_first=True)

# Ensure the test DataFrame has the same columns as the training set
# Get columns used during training
train_columns = X[selected_features_rfe].columns

# Reindex the test DataFrame
X_test_final = test_df.reindex(columns=train_columns, fill_value=0)

# Make predictions on the test set
predictions = final_model.predict(X_test_final)

# Create a submission DataFrame
submission_df = pd.DataFrame({
    'PassengerId': test_df['PassengerId'],
    'Survived': predictions
})

# Save submission to CSV
submission_df.to_csv('submission.csv', index=False)
print("Submission file created: submission.csv")
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_2512\140188536.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_df['Age'].fillna(train_df['Age'].median(), inplace=True)
# C:\Users\user\AppData\Local\Temp\ipykernel_2512\140188536.py:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_df['Embarked'].fillna(train_df['Embarked'].mode()[0], inplace=True)
# [I 2024-10-30 19:11:20,223] A new study created in memory with name: no-name-38079fed-ac9b-49dd-a029-eea48cb79083
# [I 2024-10-30 19:11:20,385] Trial 0 finished with value: 0.8268156424581006 and parameters: {'n_estimators': 99, 'max_depth': 16}. Best is trial 0 with value: 0.8268156424581006.
# Selected Features using RFE: ['PassengerId', 'Pclass', 'Age', 'Fare', 'Sex_male']
# [I 2024-10-30 19:11:20,595] Trial 1 finished with value: 0.8044692737430168 and parameters: {'n_estimators': 141, 'max_depth': 14}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:20,771] Trial 2 finished with value: 0.8100558659217877 and parameters: {'n_estimators': 119, 'max_depth': 17}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:20,932] Trial 3 finished with value: 0.8100558659217877 and parameters: {'n_estimators': 108, 'max_depth': 18}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:21,047] Trial 4 finished with value: 0.7988826815642458 and parameters: {'n_estimators': 82, 'max_depth': 7}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:21,321] Trial 5 finished with value: 0.8044692737430168 and parameters: {'n_estimators': 187, 'max_depth': 14}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:21,467] Trial 6 finished with value: 0.8156424581005587 and parameters: {'n_estimators': 104, 'max_depth': 11}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:21,621] Trial 7 finished with value: 0.8212290502793296 and parameters: {'n_estimators': 102, 'max_depth': 13}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:21,826] Trial 8 finished with value: 0.8268156424581006 and parameters: {'n_estimators': 151, 'max_depth': 8}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:22,084] Trial 9 finished with value: 0.8044692737430168 and parameters: {'n_estimators': 186, 'max_depth': 16}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:22,166] Trial 10 finished with value: 0.7821229050279329 and parameters: {'n_estimators': 53, 'max_depth': 1}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:22,375] Trial 11 finished with value: 0.7988826815642458 and parameters: {'n_estimators': 152, 'max_depth': 7}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:22,609] Trial 12 finished with value: 0.8100558659217877 and parameters: {'n_estimators': 156, 'max_depth': 20}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:22,718] Trial 13 finished with value: 0.8100558659217877 and parameters: {'n_estimators': 75, 'max_depth': 8}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:22,884] Trial 14 finished with value: 0.7877094972067039 and parameters: {'n_estimators': 136, 'max_depth': 3}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:23,130] Trial 15 finished with value: 0.8156424581005587 and parameters: {'n_estimators': 161, 'max_depth': 10}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:23,242] Trial 16 finished with value: 0.7932960893854749 and parameters: {'n_estimators': 83, 'max_depth': 4}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:23,514] Trial 17 finished with value: 0.8100558659217877 and parameters: {'n_estimators': 175, 'max_depth': 11}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:23,810] Trial 18 finished with value: 0.8044692737430168 and parameters: {'n_estimators': 199, 'max_depth': 20}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:23,999] Trial 19 finished with value: 0.8212290502793296 and parameters: {'n_estimators': 127, 'max_depth': 8}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:24,094] Trial 20 finished with value: 0.8156424581005587 and parameters: {'n_estimators': 55, 'max_depth': 13}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:24,259] Trial 21 finished with value: 0.8212290502793296 and parameters: {'n_estimators': 97, 'max_depth': 15}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:24,434] Trial 22 finished with value: 0.8156424581005587 and parameters: {'n_estimators': 116, 'max_depth': 12}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:24,589] Trial 23 finished with value: 0.8212290502793296 and parameters: {'n_estimators': 97, 'max_depth': 9}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:24,685] Trial 24 finished with value: 0.7932960893854749 and parameters: {'n_estimators': 67, 'max_depth': 5}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:24,889] Trial 25 finished with value: 0.8100558659217877 and parameters: {'n_estimators': 130, 'max_depth': 18}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:25,101] Trial 26 finished with value: 0.8100558659217877 and parameters: {'n_estimators': 141, 'max_depth': 13}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:25,267] Trial 27 finished with value: 0.8212290502793296 and parameters: {'n_estimators': 92, 'max_depth': 16}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:25,417] Trial 28 finished with value: 0.8044692737430168 and parameters: {'n_estimators': 111, 'max_depth': 6}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:25,682] Trial 29 finished with value: 0.8100558659217877 and parameters: {'n_estimators': 171, 'max_depth': 14}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:25,901] Trial 30 finished with value: 0.8156424581005587 and parameters: {'n_estimators': 150, 'max_depth': 10}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:26,086] Trial 31 finished with value: 0.8044692737430168 and parameters: {'n_estimators': 123, 'max_depth': 9}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:26,287] Trial 32 finished with value: 0.8156424581005587 and parameters: {'n_estimators': 128, 'max_depth': 12}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:26,466] Trial 33 finished with value: 0.8100558659217877 and parameters: {'n_estimators': 118, 'max_depth': 8}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:26,686] Trial 34 finished with value: 0.8156424581005587 and parameters: {'n_estimators': 145, 'max_depth': 18}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:26,834] Trial 35 finished with value: 0.7932960893854749 and parameters: {'n_estimators': 107, 'max_depth': 6}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:27,034] Trial 36 finished with value: 0.8044692737430168 and parameters: {'n_estimators': 134, 'max_depth': 15}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:27,172] Trial 37 finished with value: 0.8156424581005587 and parameters: {'n_estimators': 85, 'max_depth': 12}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:27,329] Trial 38 finished with value: 0.8044692737430168 and parameters: {'n_estimators': 101, 'max_depth': 17}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:27,485] Trial 39 finished with value: 0.8044692737430168 and parameters: {'n_estimators': 113, 'max_depth': 8}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:27,601] Trial 40 finished with value: 0.7430167597765364 and parameters: {'n_estimators': 91, 'max_depth': 2}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:27,767] Trial 41 finished with value: 0.8212290502793296 and parameters: {'n_estimators': 101, 'max_depth': 15}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:27,884] Trial 42 finished with value: 0.8268156424581006 and parameters: {'n_estimators': 70, 'max_depth': 15}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:27,992] Trial 43 finished with value: 0.8156424581005587 and parameters: {'n_estimators': 61, 'max_depth': 16}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:28,101] Trial 44 finished with value: 0.8212290502793296 and parameters: {'n_estimators': 72, 'max_depth': 14}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:28,243] Trial 45 finished with value: 0.8100558659217877 and parameters: {'n_estimators': 78, 'max_depth': 19}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:28,443] Trial 46 finished with value: 0.8156424581005587 and parameters: {'n_estimators': 122, 'max_depth': 11}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:28,567] Trial 47 finished with value: 0.7988826815642458 and parameters: {'n_estimators': 88, 'max_depth': 7}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:28,835] Trial 48 finished with value: 0.8044692737430168 and parameters: {'n_estimators': 171, 'max_depth': 13}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:28,919] Trial 49 finished with value: 0.8100558659217877 and parameters: {'n_estimators': 51, 'max_depth': 9}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:29,185] Trial 50 finished with value: 0.8100558659217877 and parameters: {'n_estimators': 164, 'max_depth': 16}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:29,351] Trial 51 finished with value: 0.8156424581005587 and parameters: {'n_estimators': 95, 'max_depth': 15}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:29,529] Trial 52 finished with value: 0.8156424581005587 and parameters: {'n_estimators': 106, 'max_depth': 17}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:29,658] Trial 53 finished with value: 0.8268156424581006 and parameters: {'n_estimators': 79, 'max_depth': 14}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:29,785] Trial 54 finished with value: 0.8268156424581006 and parameters: {'n_estimators': 79, 'max_depth': 14}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:29,903] Trial 55 finished with value: 0.8212290502793296 and parameters: {'n_estimators': 68, 'max_depth': 14}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:30,031] Trial 56 finished with value: 0.8268156424581006 and parameters: {'n_estimators': 79, 'max_depth': 13}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:30,163] Trial 57 finished with value: 0.8156424581005587 and parameters: {'n_estimators': 79, 'max_depth': 12}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:30,260] Trial 58 finished with value: 0.8156424581005587 and parameters: {'n_estimators': 58, 'max_depth': 14}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:30,370] Trial 59 finished with value: 0.8044692737430168 and parameters: {'n_estimators': 66, 'max_depth': 17}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:30,484] Trial 60 finished with value: 0.8212290502793296 and parameters: {'n_estimators': 73, 'max_depth': 13}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:30,618] Trial 61 finished with value: 0.8268156424581006 and parameters: {'n_estimators': 83, 'max_depth': 15}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:30,768] Trial 62 finished with value: 0.8268156424581006 and parameters: {'n_estimators': 82, 'max_depth': 15}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:30,886] Trial 63 finished with value: 0.8212290502793296 and parameters: {'n_estimators': 63, 'max_depth': 16}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:31,018] Trial 64 finished with value: 0.8212290502793296 and parameters: {'n_estimators': 76, 'max_depth': 14}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:31,141] Trial 65 finished with value: 0.8156424581005587 and parameters: {'n_estimators': 71, 'max_depth': 10}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:31,267] Trial 66 finished with value: 0.8156424581005587 and parameters: {'n_estimators': 87, 'max_depth': 18}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:31,400] Trial 67 finished with value: 0.8100558659217877 and parameters: {'n_estimators': 83, 'max_depth': 17}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:31,534] Trial 68 finished with value: 0.8212290502793296 and parameters: {'n_estimators': 79, 'max_depth': 11}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:31,634] Trial 69 finished with value: 0.8212290502793296 and parameters: {'n_estimators': 58, 'max_depth': 13}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:31,784] Trial 70 finished with value: 0.8212290502793296 and parameters: {'n_estimators': 92, 'max_depth': 15}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:31,917] Trial 71 finished with value: 0.8268156424581006 and parameters: {'n_estimators': 82, 'max_depth': 15}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:32,034] Trial 72 finished with value: 0.8156424581005587 and parameters: {'n_estimators': 69, 'max_depth': 16}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:32,170] Trial 73 finished with value: 0.8212290502793296 and parameters: {'n_estimators': 76, 'max_depth': 14}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:32,300] Trial 74 finished with value: 0.8100558659217877 and parameters: {'n_estimators': 89, 'max_depth': 16}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:32,442] Trial 75 finished with value: 0.8268156424581006 and parameters: {'n_estimators': 83, 'max_depth': 15}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:32,593] Trial 76 finished with value: 0.8156424581005587 and parameters: {'n_estimators': 96, 'max_depth': 12}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:32,701] Trial 77 finished with value: 0.8212290502793296 and parameters: {'n_estimators': 62, 'max_depth': 13}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:32,830] Trial 78 finished with value: 0.8268156424581006 and parameters: {'n_estimators': 80, 'max_depth': 14}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:33,002] Trial 79 finished with value: 0.8100558659217877 and parameters: {'n_estimators': 102, 'max_depth': 19}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:33,125] Trial 80 finished with value: 0.8268156424581006 and parameters: {'n_estimators': 74, 'max_depth': 15}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:33,266] Trial 81 finished with value: 0.8268156424581006 and parameters: {'n_estimators': 83, 'max_depth': 15}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:33,400] Trial 82 finished with value: 0.8212290502793296 and parameters: {'n_estimators': 86, 'max_depth': 15}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:33,735] Trial 83 finished with value: 0.8044692737430168 and parameters: {'n_estimators': 197, 'max_depth': 16}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:33,885] Trial 84 finished with value: 0.8268156424581006 and parameters: {'n_estimators': 94, 'max_depth': 13}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:34,010] Trial 85 finished with value: 0.8044692737430168 and parameters: {'n_estimators': 64, 'max_depth': 17}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:34,139] Trial 86 finished with value: 0.8100558659217877 and parameters: {'n_estimators': 71, 'max_depth': 14}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:34,278] Trial 87 finished with value: 0.7988826815642458 and parameters: {'n_estimators': 98, 'max_depth': 6}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:34,400] Trial 88 finished with value: 0.8156424581005587 and parameters: {'n_estimators': 76, 'max_depth': 16}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:34,553] Trial 89 finished with value: 0.8156424581005587 and parameters: {'n_estimators': 89, 'max_depth': 15}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:34,775] Trial 90 finished with value: 0.8044692737430168 and parameters: {'n_estimators': 146, 'max_depth': 13}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:34,900] Trial 91 finished with value: 0.8268156424581006 and parameters: {'n_estimators': 82, 'max_depth': 14}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:35,034] Trial 92 finished with value: 0.8268156424581006 and parameters: {'n_estimators': 84, 'max_depth': 15}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:35,173] Trial 93 finished with value: 0.8268156424581006 and parameters: {'n_estimators': 81, 'max_depth': 15}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:35,347] Trial 94 finished with value: 0.8156424581005587 and parameters: {'n_estimators': 110, 'max_depth': 14}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:35,468] Trial 95 finished with value: 0.8156424581005587 and parameters: {'n_estimators': 67, 'max_depth': 16}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:35,711] Trial 96 finished with value: 0.8100558659217877 and parameters: {'n_estimators': 157, 'max_depth': 17}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:35,835] Trial 97 finished with value: 0.7988826815642458 and parameters: {'n_estimators': 91, 'max_depth': 4}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:35,977] Trial 98 finished with value: 0.8100558659217877 and parameters: {'n_estimators': 86, 'max_depth': 18}. Best is trial 0 with value: 0.8268156424581006.
# [I 2024-10-30 19:11:36,100] Trial 99 finished with value: 0.8156424581005587 and parameters: {'n_estimators': 78, 'max_depth': 12}. Best is trial 0 with value: 0.8268156424581006.
# C:\Users\user\AppData\Local\Temp\ipykernel_2512\140188536.py:62: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test_df['Age'].fillna(test_df['Age'].median(), inplace=True)
# C:\Users\user\AppData\Local\Temp\ipykernel_2512\140188536.py:63: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test_df['Embarked'].fillna(test_df['Embarked'].mode()[0], inplace=True)
# Best Trial:
#   Value: 0.8268156424581006
#   Params:
#     n_estimators: 99
#     max_depth: 16
# Submission file created: submission.csv
